# %%
import tensorflow as tf;import numpy as np; import os; import h5py
import matplotlib.pyplot as plt;import scipy.misc as sp
# %matplotlib inline

# %%
ls
# Out:
# camvid_match_labels.txt  lej_colormap.txt      segnet_train_atrous.py
# color_map.py             lej_match_labels.txt  segnet_train_none.py
# color_map.pyc            match_labels.txt      segnet_train_top.py
# gan_keras.py             mnist.h5              segnet_vgg16_sync.py
# gan_output               README.md             train_log_file
# gan.py                   results/              utils_mod_none.py
# image_reader.py          results.ipynb         utils_mod.py
# image_reader.pyc         script.py             utils_mod.pyc

# %%
tr=np.load('./results/arl segnet results/train_conf_matrix.npy')[0:8,0:8]
va=np.load('./results/arl segnet results/val_conf_matrix.npy')[0:8,0:8]
te=np.load('./results/arl segnet results/test_conf_matrix.npy')[0:8,0:8]

# %%
file1=open(os.path.join('camvid_match_labels.txt'))
match_labels=file1.readlines()
file1.close()
match_labels=[line.splitlines()[0].split(' ') for line in match_labels]

# %%
camvid_objects=[rt[1] for rt in match_labels]
arl_objects=['sky','tree','car','grass','building','object','road','sidewalk']

# %%
plt.imshow(tr)
plt.colorbar()
plt.xticks(range(8),arl_objects,rotation='vertical')
plt.yticks(range(8),arl_objects,rotation='horizontal')
# Out:
# ([<matplotlib.axis.YTick at 0x7f58c4507ed0>,
#   <matplotlib.axis.YTick at 0x7f58c44fcdd0>,
#   <matplotlib.axis.YTick at 0x7f58c43c7750>,
#   <matplotlib.axis.YTick at 0x7f58c43c7c90>,
#   <matplotlib.axis.YTick at 0x7f58c43d3210>,
#   <matplotlib.axis.YTick at 0x7f58c43d3910>,
#   <matplotlib.axis.YTick at 0x7f58c43dd050>,
#   <matplotlib.axis.YTick at 0x7f58c43bded0>],
#  <a list of 8 Text yticklabel objects>)

# %%
plt.imshow(va)
plt.colorbar()
plt.xticks(range(8),arl_objects,rotation='vertical')
plt.yticks(range(8),arl_objects,rotation='horizontal')
# Out:
# ([<matplotlib.axis.YTick at 0x7f58c4433f50>,
#   <matplotlib.axis.YTick at 0x7f58c441a2d0>,
#   <matplotlib.axis.YTick at 0x7f58c0b5d850>,
#   <matplotlib.axis.YTick at 0x7f58c43a3c50>,
#   <matplotlib.axis.YTick at 0x7f58c441a210>,
#   <matplotlib.axis.YTick at 0x7f58c0a69450>,
#   <matplotlib.axis.YTick at 0x7f58c0a69950>,
#   <matplotlib.axis.YTick at 0x7f58c0a69e50>],
#  <a list of 8 Text yticklabel objects>)

# %%
plt.imshow(te)
plt.colorbar()
plt.xticks(range(8),arl_objects,rotation='vertical')
plt.yticks(range(8),arl_objects,rotation='horizontal')
# Out:
# ([<matplotlib.axis.YTick at 0x7f58c0a20ed0>,
#   <matplotlib.axis.YTick at 0x7f58c0a20d50>,
#   <matplotlib.axis.YTick at 0x7f58c08bdfd0>,
#   <matplotlib.axis.YTick at 0x7f58c08c5550>,
#   <matplotlib.axis.YTick at 0x7f58c08c5a90>,
#   <matplotlib.axis.YTick at 0x7f58c08cf1d0>,
#   <matplotlib.axis.YTick at 0x7f58c08cf8d0>,
#   <matplotlib.axis.YTick at 0x7f58c08cffd0>],
#  <a list of 8 Text yticklabel objects>)

# %%
plt.imshow(te)
plt.colorbar()
plt.xticks(range(8),arl_objects,rotation='vertical')
plt.yticks(range(8),arl_objects,rotation='horizontal')
# Out:
# ([<matplotlib.axis.YTick at 0x7f58c088b190>,
#   <matplotlib.axis.YTick at 0x7f58c0b41f90>,
#   <matplotlib.axis.YTick at 0x7f58c07a2cd0>,
#   <matplotlib.axis.YTick at 0x7f58c07aa250>,
#   <matplotlib.axis.YTick at 0x7f58c07aa790>,
#   <matplotlib.axis.YTick at 0x7f58c07aae90>,
#   <matplotlib.axis.YTick at 0x7f58c07345d0>,
#   <matplotlib.axis.YTick at 0x7f58c0734cd0>],
#  <a list of 8 Text yticklabel objects>)

# %%
s_tr=np.sum(tr,axis=1)
s_va=np.sum(va,axis=1)
s_te=np.sum(te,axis=1)

# %%
n_tr=tr/np.tile(s_tr.reshape(-1,1),[1,tr.shape[0]])
n_va=va/np.tile(s_va.reshape(-1,1),[1,tr.shape[0]])
n_te=te/np.tile(s_te.reshape(-1,1),[1,tr.shape[0]])

# %%
plt.bar(range(8),te[1,:])
plt.xticks(range(8),arl_objects,rotation='vertical')
plt.yticks(range(8),arl_objects,rotation='horizontal')
# Out:
# ([<matplotlib.axis.YTick at 0x7f58c0919cd0>,
#   <matplotlib.axis.YTick at 0x7f58c050ead0>,
#   <matplotlib.axis.YTick at 0x7f58c024a890>,
#   <matplotlib.axis.YTick at 0x7f58c024add0>,
#   <matplotlib.axis.YTick at 0x7f58c0252350>,
#   <matplotlib.axis.YTick at 0x7f58c0252a50>,
#   <matplotlib.axis.YTick at 0x7f58c025c190>,
#   <matplotlib.axis.YTick at 0x7f58c025c490>],
#  <a list of 8 Text yticklabel objects>)

# %%
plt.plot(np.diag(n_te))

# %%
tr
# Out:
# array([[  2.01746900e+06,   3.91300000e+03,   5.00000000e+01,
#           0.00000000e+00,   3.09231000e+05,   1.06690000e+04,
#           1.70000000e+01,   8.00000000e+00],
#        [  2.28610000e+04,   1.69658000e+05,   1.17800000e+03,
#           0.00000000e+00,   2.23534000e+05,   1.82440000e+04,
#           1.91000000e+02,   3.03000000e+02],
#        [  3.89000000e+02,   1.16500000e+03,   3.17790000e+04,
#           0.00000000e+00,   1.13620000e+04,   7.17000000e+02,
#           6.20000000e+01,   6.63000000e+02],
#        [  1.95430000e+04,   4.29914800e+06,   1.92980000e+04,
#           0.00000000e+00,   2.11507000e+05,   5.44490000e+04,
#           2.05044000e+05,   3.29950000e+05],
#        [  2.15659000e+05,   5.27190000e+04,   8.71630000e+04,
#           0.00000000e+00,   3.06269000e+06,   1.87969000e+05,
#           7.32400000e+03,   7.74830000e+04],
#        [  2.84800000e+03,   1.55420000e+04,   5.29340000e+04,
#           0.00000000e+00,   6.79220000e+04,   4.68360000e+04,
#           1.92100000e+03,   7.15200000e+03],
#        [  1.08300000e+03,   8.54800000e+04,   2.44950000e+04,
#           0.00000000e+00,   1.09129000e+05,   1.17760000e+04,
#           3.50453800e+06,   4.30651000e+05],
#        [  7.90000000e+01,   2.77700000e+03,   4.00000000e+02,
#           0.00000000e+00,   2.50500000e+03,   2.91900000e+03,
#           6.00000000e+01,   2.86300000e+03]])
